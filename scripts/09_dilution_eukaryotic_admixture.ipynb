# %%
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib.colors import ListedColormap

new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
matplotlib.rcParams.update(new_rc_params)

# %%
# dilution heatmap
df = pd.read_csv('../dilution_heatmap.csv', index_col=0)
cmap = sns.cubehelix_palette(start=.2, rot=-.3, n_colors=3)
sns.heatmap(df, linewidths=0.5, cmap=ListedColormap(cmap), cbar_kws={'label': 'Sample dilution (log)'})
plt.savefig('../plots/dilution_heatmap.pdf', format='pdf', bbox_inches='tight')
